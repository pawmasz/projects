# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *

# Loading your IBM Q account(s)
provider = IBMQ.load_account()
backend = provider.backend.ibmq_qasm_simulator

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

# %%
qreg_q = QuantumRegister(3, 'q')
circuit = QuantumCircuit(qreg_q)

# %%
circuit.ry(1.43, qreg_q[0])
circuit.ry(2.9, qreg_q[1])
circuit.ry(1.47, qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.ry(1.1, qreg_q[0])
circuit.ry(-0.93, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[2])
circuit.ry(-9.8e-2, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.ry(9.8e-2, qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[2])
circuit.ry(-0.29, qreg_q[2])
circuit.rx(3.14, qreg_q[2])
circuit.ry(0.29, qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[2])
circuit.ry(-9.8e-2, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.ry(0.93, qreg_q[1])
circuit.ry(9.8e-2, qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[2])
circuit.ry(-1.1, qreg_q[0])
circuit.ry(-3.14, qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.ry(-1.47, qreg_q[2])
circuit.ry(-1.43, qreg_q[0])
circuit.ry(-2.9, qreg_q[1])
circuit.rz(-0.79, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.79, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[0])
circuit.rz(-0.79, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.79, qreg_q[0])
circuit.rz(-0.79, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[0])
circuit.ry(1.43, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.79, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.ry(2.9, qreg_q[1])
circuit.rz(-0.79, qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.ry(1.47, qreg_q[2])
circuit.ry(1.1, qreg_q[0])
circuit.ry(-0.93, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[2])
circuit.ry(-9.8e-2, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.ry(9.8e-2, qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[2])
circuit.ry(-0.29, qreg_q[2])

# %%
circuit.draw('mpl')

# %%
circuit.measure_all()

# %%
circuit.draw('mpl')

# %%
transpiled = transpile(circuit, backend)

# %%
job = backend.run(transpiled)

# %%
job_result = job.result()

# %%
counts = job_result.get_counts(circuit)

# %%
from qiskit.visualization import plot_histogram
plot_histogram(counts)
